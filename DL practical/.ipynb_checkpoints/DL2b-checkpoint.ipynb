# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import to_categorical

# %%
# Load data
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/letter-recognition/letter-recognition.data"
columns = ['letter'] + [f'feature_{i}' for i in range(1,17)]

df = pd.read_csv(url, header=None, names=columns)

print(df.head())
# Out:
#   letter  feature_1  feature_2  feature_3  feature_4  feature_5  feature_6  \
# 0      T          2          8          3          5          1          8
# 1      I          5         12          3          7          2         10
# 2      D          4         11          6          8          6         10
# 3      N          7         11          6          6          3          5
# 4      G          2          1          3          1          1          8
#
#    feature_7  feature_8  feature_9  feature_10  feature_11  feature_12  \
# 0         13          0          6           6          10           8
# 1          5          5          4          13           3           9
# 2          6          2          6          10           3           7
# 3          9          4          6           4           4          10
# 4          6          6          6           6           5           9
#
#    feature_13  feature_14  feature_15  feature_16
# 0           0           8           0           8
# 1           2           8           4          10
# 2           3           7           3           9
# 3           6          10           2           8
# 4           1           7           5          10

# %%
X = df.iloc[:, 1:].values
y = df.iloc[:, 0].values

# %%
le = LabelEncoder()
y_encoded = le.fit_transform(y)

# %%
y_categorical = to_categorical(y_encoded)

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y_categorical, test_size=0.2, random_state=42
)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input

model = Sequential()

model.add(Input(shape=(16,)))   # ✅ Correct way
model.add(Dense(128, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(26, activation='softmax'))

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
history = model.fit(
    X_train, y_train,
    epochs=30,
    batch_size=32,
    validation_split=0.2
)
# Out:
# Epoch 1/30
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5656 - loss: 1.6125 - val_accuracy: 0.7428 - val_loss: 0.9271
# Epoch 2/30
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7897 - loss: 0.7450 - val_accuracy: 0.8197 - val_loss: 0.6437
# Epoch 3/30
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8354 - loss: 0.5584 - val_accuracy: 0.8491 - val_loss: 0.5233
# Epoch 4/30
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8677 - loss: 0.4486 - val_accuracy: 0.8728 - val_loss: 0.4309
# Epoch 5/30
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8898 - loss: 0.3774 - val_accuracy: 0.8822 - val_loss: 0.3814
# Epoch 6/30
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9047 - loss: 0.3234 - val_accuracy: 0.8969 - val_loss: 0.3324
# Epoch 7/30
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9144 - loss: 0.2859 - val_accuracy: 0.9047 - val_loss: 0.3042
# Epoch 8/30
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9245 - loss: 0.2549 - val_accuracy: 0.9159 - val_loss: 0.2764
# Epoch 9/30
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9308 - loss: 0.2278 - val_accuracy: 0.9191 - val_loss: 0.2611
# Epoch 10/30
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9381 - loss: 0.2062 - val_accuracy: 0.9197 - val_loss: 0.2559
# Epoch 11/30
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9406 - loss: 0.1909 - val_accuracy: 0.9237 - val_loss: 0.2307
# Epoch 12/30
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9475 - loss: 0.1739 - val_accuracy: 0.9331 - val_loss: 0.2181
# Epoch 13/30
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9508 - loss: 0.1615 - val_accuracy: 0.9337 - val_loss: 0.2121
# Epoch 14/30
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9537 - loss: 0.1497 - val_accuracy: 0.9391 - val_loss: 0.2005
# Epoch 15/30
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9576 - loss: 0.1372 - val_accuracy: 0.9312 - val_loss: 0.2042
# Epoch 16/30
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9605 - loss: 0.1313 - val_accuracy: 0.9381 - val_loss: 0.1933
# Epoch 17/30
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9621 - loss: 0.1203 - val_accuracy: 0.9369 - val_loss: 0.1853
# Epoch 18/30
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9659 - loss: 0.1131 - val_accuracy: 0.9431 - val_loss: 0.1781
# Epoch 19/30
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9681 - loss: 0.1076 - val_accuracy: 0.9413 - val_loss: 0.1818
# Epoch 20/30
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9701 - loss: 0.0991 - val_accuracy: 0.9441 - val_loss: 0.1778
# Epoch 21/30
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9708 - loss: 0.0951 - val_accuracy: 0.9484 - val_loss: 0.1673
# Epoch 22/30
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9736 - loss: 0.0874 - val_accuracy: 0.9456 - val_loss: 0.1673
# Epoch 23/30
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9777 - loss: 0.0788 - val_accuracy: 0.9491 - val_loss: 0.1612
# Epoch 24/30
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9761 - loss: 0.0796 - val_accuracy: 0.9503 - val_loss: 0.1584
# Epoch 25/30
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9768 - loss: 0.0751 - val_accuracy: 0.9469 - val_loss: 0.1688
# Epoch 26/30
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9777 - loss: 0.0696 - val_accuracy: 0.9484 - val_loss: 0.1647
# Epoch 27/30
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9809 - loss: 0.0638 - val_accuracy: 0.9538 - val_loss: 0.1467
# Epoch 28/30
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9820 - loss: 0.0620 - val_accuracy: 0.9438 - val_loss: 0.1688
# Epoch 29/30
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9837 - loss: 0.0568 - val_accuracy: 0.9488 - val_loss: 0.1638
# Epoch 30/30
# 400/400 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9841 - loss: 0.0556 - val_accuracy: 0.9500 - val_loss: 0.1544

# %%
loss, accuracy = model.evaluate(X_test, y_test)
print("Test Accuracy:", accuracy)
# Out:
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9492 - loss: 0.1562
# Test Accuracy: 0.9492499828338623

# %%
pred = model.predict(X_test)

# Convert probabilities → class index
pred_classes = np.argmax(pred, axis=1)

# Convert back to letters
pred_letters = le.inverse_transform(pred_classes)

print(pred_letters[:10])
# Out:
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 951us/step
# ['Z' 'L' 'A' 'E' 'Q' 'E' 'O' 'Q' 'G' 'O']
